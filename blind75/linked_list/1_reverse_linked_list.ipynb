# %% [markdown]
# Given the beginning of a singly linked list head, reverse the list, and return the new beginning of the list.
#
# Example 1:
#
# Input: head = [0,1,2,3]
#
# Output: [3,2,1,0]
#
# Example 2:
#
# Input: head = []
#
# Output: []

# %%
# Definition for singly-linked list.
from typing import Optional

class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

# %% [markdown]
# # Iteration

# %% [markdown]
# Reversing a linked list iteratively is all about flipping pointers one step at a time.
#
# We walk through the list from left to right, and for each node, we redirect its next pointer to point to the node behind it.
#
# To avoid losing track of the rest of the list, we keep three pointers:
#
# curr → the current node we are processing
#
# prev → the node that should come after curr once reversed
#
# temp → the original next node (so we don't break the chain)
#
# By moving these pointers forward in each step, we gradually reverse the entire list.
#
# When curr becomes null, the list is fully reversed, and prev points to the new head.
#
# Algorithm
#
# Initialize:
#
# prev = null
#
# curr = head
#
# While curr exists:
#
# Save the next node: temp = curr.next
#
# Reverse the pointer: curr.next = prev
#
# Move prev to curr
#
# Move curr to temp
#
# When the loop ends, prev is the new head of the reversed list.
#
# Return prev.

# %%
# Iteration
# Time Complexity: O(n)
# Space Complexity: O(1)
class Solution:
    def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        head_prev = None
        current = head
        while current:
            next_node = current.next # Store next node
            current.next = head_prev # Reverse the link
            head_prev = current      # Move head_prev to current
            current = next_node      # Move to next node
        return head_prev

# %% [markdown]
# # Recursion

# %% [markdown]
# Reversing a linked list using recursion works by thinking in terms of "reverse the rest, then fix the pointer for the current node."
#
# When we recursively go to the end of the list, that last node becomes the new head.
#
# While the recursion unwinds, each node points backward to the one that called it.
#
# Finally, we set the original head's next to null to finish the reversal.
#
# This approach uses the call stack to naturally reverse the direction of the pointers.
#
# Algorithm
#
# If the list is empty, return null.
#
# Recursively call the function on head.next to reverse the rest of the list.
#
# After the recursive call returns:
#
# Make head.next.next = head so the next node points back to the current node.
#
# Set head.next = null to avoid cycles.
#
# Return the new head returned by the deepest recursive call.

# %%
# Recursion
# Time Complexity: O(n)
# Space Complexity: O(n)
class Solution:
    def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        if not head:
            return head
        
        newHead = head  # Initialize newHead to head
        if head.next:  # If there is a next node
            newHead = self.reverseList(head.next)  # Recurse on next node
            head.next.next = head  # Reverse the link
        head.next = None # Set the next of current head to None

        return newHead

# %%
# Use
node3 = ListNode(3)
node2 = ListNode(2, node3)
node1 = ListNode(1, node2)

head = node1   # head points to 1

sol = Solution()
new_head = sol.reverseList(head)

print(new_head.val)  # Should print 3
print(new_head.next.val)  # Should print 2
print(new_head.next.next.val)  # Should print 1
print(new_head.next.next.next)  # Should print None
# Out:
# 3
# 2
# 1
# None
